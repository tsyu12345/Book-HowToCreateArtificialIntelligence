# %% [markdown]
# # 3.人工知能の根底にあるもの-AIの基本概念-

# %% [markdown]
# ## 反射から自律へ-感覚と身体をつなぐ情報の経路-
#
# * 動物には`反射性`と`自律性`の2つの側面がある。
#   * 反射性とは、本能に基づいて自らの存在を守ろうとするときに発生する行動（Ex.捕食者がきたら逃げるなど）
#   * 自律性とは、自らの意志によって行動を選択するときに発生する行動（Ex.食べ物を探すなど）
# 動物の多くは、この反射性の積み重ねの上に、現在の人間のような知性が誕生したという見方もある。
#
# 人間など多くの動物は自らの意思決定に従って行動を選択することができる。しかし、どんなに高度な動物も追いつめられると、行動する前の思考が働かなくなるので、どんどん反射的な行動になっていく。
#
# すなわち、人間や動物は反射性と自律性という相反する2つの側面を持っているということである。
# * 例えば、「おなかが空いたから食べ物を食べたい」と「今は作業中だから空腹でも我慢して作業をすすめよう」
# * 上の２つは互いに相反する知性であり、まさに反射性と自律性が競合して知性を形成している証でもある。
# また、この性質は知能を作る上で一番重要な概念。両者をバランスよく調和させるように実装することが重要。
#
# 「反射から自律へ」の言葉通り、反射性から自律性へと進化させるという指針は、ゲームAIの開発においても有効な指針となる。
# まず、そのキャラクターがどのような反射的な知性を持つか定義し、その1つ1つを実装していく。

# %% [markdown]
# ## モジュラーデザインを作る-中央集中構造、多層構造、階層構造、サブサンプション構造-
#
# 人工知能をつくるときは、ある知的機能に特化したモジュール・部品を作成し、それをそれぞれ連携統合して構成する。これを、`モジューラーデザイン`と呼ぶ。
# * 例えば、視覚機能のみをもつモジュール、身体を動かすだけのモジュールなど…
# * この1つ1つのモジュールを`知能モジュール`と呼ぶ。
#
# このモジュラーデザインには大きく`中央集中型`と`多層構造型`がある。
#
# * 中央集中型
#   * すべての課題・情報を1つの知能モジュールに集中させ、解答を出力する構造。
#   * 扱うべき情報量が多いとどこかでパンクする。
#   * また、扱うべき問題のフレームがバラバラなので、人工知能にとっては相性が悪い。
# * 多層構造型
#   * ゲームAIの基本的なモジュール構造。
#   * 扱う知性・知能を複数のモジュールに分散し、それぞれ並列に動作させ、最後の出力を統合する。
#   * しかし、この方法では各層間の調整は効かないので、入力情報の振り分けや、出力情報の統合が必要になる。
